# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load data

# %%
df_raw = pd.read_csv("KaDo.csv")

# Hello darkness my hold friend
# df_raw[df_raw["FAMILLE"] == "SANTE NATURELLE"]
# Out:
#          TICKET_ID  MOIS_VENTE  PRIX_NET          FAMILLE     UNIVERS  \
# 6458712   33072287           1     14.95  SANTE NATURELLE  DIETETIQUE
#
#              MAILLE                        LIBELLE     CLI_ID
# 6458712  DIETETIQUE  SOIN COSM ORALE 3X10 CAPS RC2  993646584

# %% [markdown]
# ## Copy raw df

# %%
df = df_raw

# %% [markdown]
# ## Show clean df

# %%
df
# Out:
#          TICKET_ID  MOIS_VENTE  PRIX_NET          FAMILLE  \
# 0         35592159          10      1.67          HYGIENE
# 1         35592159          10      1.66          HYGIENE
# 2         35592159          10      7.45  SOINS DU VISAGE
# 3         35592159          10      5.95  SOINS DU VISAGE
# 4         35592159          10      1.67          HYGIENE
# ...            ...         ...       ...              ...
# 7245517   35448190           9      2.50   SOINS DU CORPS
# 7245518   35448190           9      3.00          HYGIENE
# 7245519   36105678          12      7.90       MAQUILLAGE
# 7245520   36105678          12     11.45       MAQUILLAGE
# 7245521   36105678          12      4.45       MAQUILLAGE
#
#                              UNIVERS                       MAILLE  \
# 0             HYG_DOUCHE JARDINMONDE                      HYG_JDM
# 1             HYG_DOUCHE JARDINMONDE                      HYG_JDM
# 2        VIS_CJOUR Jeunes Specifique           VIS_JEUNE_ET_LEVRE
# ...

# %% [markdown]
# ## Show labels

# %%
df_univers =df_raw[["FAMILLE"]]

df_univers["FAMILLE"].unique()
# Out:
# array(['HYGIENE', 'SOINS DU VISAGE', 'PARFUMAGE', 'SOINS DU CORPS',
#        'MAQUILLAGE', 'CAPILLAIRES', 'SOLAIRES', 'MULTI FAMILLES',
#        'SANTE NATURELLE'], dtype=object)

# %%
df_univers =df_raw[["MAILLE"]]

df_univers["MAILLE"].unique()
# Out:
# array(['HYG_JDM', 'VIS_JEUNE_ET_LEVRE', 'VIS_AAAR_DEMAQLOTION',
#        'PARF_PARFUM', 'CORPS_HYDR_LAIT_HUILE', 'HYG_PARFUMEE',
#        'MAQ_LEV_RAL_HMG', 'CORPS_HYDRA_NOURRI_ET_SOINS',
#        'CAPILLAIRE_AUTRE', 'MAQ_ONGLES', 'HYG_HOMME', 'MAQ_LEV_BASPRIX',
#        'HYG_PLAISIRNAT_BAIN_SAVON', 'MAQ_TEINT', 'HYG_CULTUREBIO',
#        'HYG_MONOI_ET_EDIT_SPEC', 'VIS_BIO', 'HYG_AUTRES',
#        'CAPILLAIRE_SHAMPOING', 'CORPS_SPA_ET_MINCEUR',
#        'VIS_AAAR_HORS_DEMAQLOTION', 'MAQ_YEUX_MASCA_EYEL_FARD', 'VIS_PUR',
#        'PARF_HOMME', 'MAQ_YEUX_CLASSIQUE', 'PARF_EDT', 'VIS_HOMMES',
#        'SOLAIRE', 'MAQ_YEUX_MASCA_HG', 'CORPS_MONOI', 'VIS_AUTRES',
#        'MAQ_AUTRE', 'MULTIFAMILLES', 'DIETETIQUE'], dtype=object)

# %%
df_univers =df_raw[["UNIVERS"]]

df_univers["UNIVERS"].unique()
# Out:
# array(['HYG_DOUCHE JARDINMONDE', 'VIS_CJOUR Jeunes Specifique',
#        'VIS_DEMAQ AAAR', 'PARF_EAUX PARFUMS',
#        'CORPS_LAIT HUILE PLAISIRNATURE', 'HYG_DOUCHE PARFUMS',
#        'CORPS_LAIT HUILE PARFUMS', 'MAQ_LEV RAL Brillance',
#        'CORPS_SOIN DES MAINS', 'CAP_AP SHAMP', 'MAQ_ONG Vernis LUM',
#        'HYG_DOUCHE HOMMES', 'MAQ_LEV BRILLANT', 'HYG_SAVONS',
#        'CORPS_LAIT HUILE AUTRES', 'CORPS_HYDRA NOURRISANT',
#        'MAQ_TEINT Fard a joues', 'CORPS_SOIN PIEDS ET JAMBES',
#        'VIS_MASQUE Jeunes Specifique', 'VIS_SOIN LEVRES',
#        'PARF_EAUX DE COLOGNE', 'HYG_DEO CULTURE BIO',
#        'HYG_DOUCHE EDT ETE', 'VIS_TRAIT BIO', 'HYG_DOUCHE HAMMAM',
#        'VIS_CJOUR BIO', 'CAP_SHAMP TRAITANT', 'CORPS_EXFOLIANT CORPS',
#        'VIS_DEMAQ Jeunes Specifique', 'VIS_CJOUR AAAR', 'MAQ_YEUX Fard',
#        'HYG_DOUCHE PLAISIRNATURE', 'VIS_DEMAQ BIO', 'VIS_DEMAQ PUR',
#        'MAQ_LEV RAL Lum4', 'PARF_EAUX HOMMES', 'MAQ_LEV RAL GrdRouge',
# ...

# %% [markdown]
# ## Nombre de Vente par Famille en fonction du Mois

# %%
df_sell_by_familly = pd.DataFrame(df_raw)
df_sell_by_familly.drop(df_sell_by_familly.columns.difference(['FAMILLE','MOIS_VENTE', 'PRIX_NET']), 1, inplace=True)
df_sell_by_familly = df_sell_by_familly.groupby(["FAMILLE", "MOIS_VENTE"], as_index=True)["MOIS_VENTE"].count()

plot_df = df_sell_by_familly.unstack().T
plot_df.plot(grid=True, lw=2, marker='.', markersize=10, title='Nombre de Vente par Famille en fonction du Mois')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

plt.show()

# %%
df_mean_by_familly = pd.DataFrame(df_raw)
df_mean_by_familly.drop(df_mean_by_familly.columns.difference(['FAMILLE','MOIS_VENTE', 'PRIX_NET']), 1, inplace=True)
df_mean_by_familly = df_mean_by_familly.groupby(["FAMILLE", "MOIS_VENTE"], as_index=True)["PRIX_NET"].mean()

plot_df = df_mean_by_familly.unstack().T
plot_df.plot(grid=True, lw=2, marker='.', markersize=10, title='Evolution du prix par Famille en fonction du Mois')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %% [markdown]
# ## Calc CA

# %%
df_ca_by_familly = pd.DataFrame(df_raw)
df_ca_by_familly.drop(df_ca_by_familly.columns.difference(['FAMILLE','MOIS_VENTE', 'PRIX_NET']), 1, inplace=True)
df_ca_by_familly = df_ca_by_familly.groupby(["FAMILLE", "MOIS_VENTE"], as_index=True)["PRIX_NET"].sum()

plot_df = df_ca_by_familly.unstack().T
plot_df
plot_df.plot(grid=True, lw=2, marker='.', markersize=10, title='CA par Famille en fonction du Mois')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

plt.show()
